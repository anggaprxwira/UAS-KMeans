# %% [markdown]
# ## IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - import
# Berguna untuk mengambil library yang tersedia pada Jupyter
# - pandas
# Library ini berguna dalam manipulasi data, menulis & membaca data,analisis, membuang data yang terdapat pada dataset, serta menampilkan data dalam bentuk gambar/grafik
# - seaborn
# Seaborn berfungsi untuk menampilkan visualisasi data, dalam kasus ini saya menggunakan seaborn dalam menampilkan data asli maupun data prediksi
# - import matplotlib.pyplot as plt
# Berfungsi untuk memaksukan data yang sudah dibuat ke pada library pandas, serta bisa untuk membuat interface yang interaktif

# %% [markdown]
# ## IMPORT DATASET

# %%
data = pd.read_csv('pmpl_southasia.csv')
data
# Out:
#      Match Played        Teams Group      Map Groups Playing  Week  Day  \
# 0               1        Celtz     A  Erangel        A B C D     1    1
# 1               1         Crwl     B  Erangel        A B C D     1    1
# 2               1     Deadeyes     D  Erangel        A B C D     1    1
# 3               0           EX     E  Erangel        A B C D     1    1
# 4               1       Fnatic     D  Erangel        A B C D     1    1
# ..            ...          ...   ...      ...            ...   ...  ...
# 495             0         SouL     B   Sanhok        A C D E     2    1
# 496             0      Tamilas     B   Sanhok        A C D E     2    1
# 497             1   TSM Entity     A   Sanhok        A C D E     2    1
# 498             1   Umumba Rxn     C   Sanhok        A C D E     2    1
# 499             1       Xtreme     E   Sanhok        A C D E     2    1
#
#      Match No  Team Match No  Chicken Dinner  Placement  Kills  Total
# ...

# %% [markdown]
# Command ini, berguna untuk mengambil file "pmpl_southasia.csv" yang sudah ditaruh dalam 1 folder dengan file jupyter yang sedang digunakan sekaran. Dan juga command "data" berguna untuk menampilkan data yang sudah kita ambil tersebut

# %%
data.head(10)
# Out:
#    Match Played       Teams Group      Map Groups Playing  Week  Day  \
# 0             1       Celtz     A  Erangel        A B C D     1    1
# 1             1        Crwl     B  Erangel        A B C D     1    1
# 2             1    Deadeyes     D  Erangel        A B C D     1    1
# 3             0          EX     E  Erangel        A B C D     1    1
# 4             1      Fnatic     D  Erangel        A B C D     1    1
# 5             0     GodLike     E  Erangel        A B C D     1    1
# 6             1        Hype     A  Erangel        A B C D     1    1
# 7             1         IND     D  Erangel        A B C D     1    1
# 8             1    Instinct     B  Erangel        A B C D     1    1
# 9             1   JyanMaara     C  Erangel        A B C D     1    1
#
#    Match No  Team Match No  Chicken Dinner  Placement  Kills  Total
# 0         1              1               0          1      2      3
# 1         1              1               0          8      3     11
# ...

# %% [markdown]
# Menampilkan 10 data teratas

# %%
data.tail(10)
# Out:
#      Match Played        Teams Group     Map Groups Playing  Week  Day  \
# 490             1       Marcos     A  Sanhok        A C D E     2    1
# 491             1    MegaStars     C  Sanhok        A C D E     2    1
# 492             1           OR     D  Sanhok        A C D E     2    1
# 493             1       PowerH     E  Sanhok        A C D E     2    1
# 494             1          SGE     C  Sanhok        A C D E     2    1
# 495             0         SouL     B  Sanhok        A C D E     2    1
# 496             0      Tamilas     B  Sanhok        A C D E     2    1
# 497             1   TSM Entity     A  Sanhok        A C D E     2    1
# 498             1   Umumba Rxn     C  Sanhok        A C D E     2    1
# 499             1       Xtreme     E  Sanhok        A C D E     2    1
#
#      Match No  Team Match No  Chicken Dinner  Placement  Kills  Total
# 490        25             21               0          4      2      6
# ...

# %% [markdown]
# Menampilkan 10 data terbawah

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Match Played    500 non-null    int64
#  1   Teams           500 non-null    object
#  2   Group           500 non-null    object
#  3   Map             500 non-null    object
#  4   Groups Playing  500 non-null    object
#  5   Week            500 non-null    int64
#  6   Day             500 non-null    int64
#  7   Match No        500 non-null    int64
#  8   Team Match No   500 non-null    int64
#  9   Chicken Dinner  500 non-null    int64
#  10  Placement       500 non-null    int64
#  11  Kills           500 non-null    int64
#  12  Total           500 non-null    int64
# dtypes: int64(9), object(4)
# memory usage: 50.9+ KB

# %% [markdown]
# Menampilkan informasi dari data pada dataset, salah 1 contohnya tipe datanya (Contoh : Integer, Float, Object, dll)

# %% [markdown]
# ## Pembentukan Model K-Means

# %%
x = data.iloc[:, [10,11]].values
x[0:10]
# Out:
# array([[ 1,  2],
#        [ 8,  3],
#        [ 1,  0],
#        [ 0,  0],
#        [ 2,  5],
#        [ 0,  0],
#        [ 4,  6],
#        [ 7,  5],
#        [ 5,  0],
#        [14,  1]], dtype=int64)

# %% [markdown]
# Menentukan data x yaitu terpadat pada kolom 10 dan 11 yang merupakan data Placement dan Kill, serta menentukan jumlah array yang digunakan yaitu 10

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %% [markdown]
# Membuat data x_scaled berdasarkan dari scaler pada data x

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state = 0)
kmeans.fit(x_scaled)
# Out:
# C:\Users\angga\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\angga\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=10, random_state=0)

# %% [markdown]
# Membagi cluster menjadi 10 bagian, dan membuat variabel x_scaled untuk mencari akurasi cluster

# %%
y_kmeans = kmeans.fit_predict(x)
y_kmeans
# Out:
# C:\Users\angga\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# C:\Users\angga\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# array([7, 5, 1, 1, 4, 1, 9, 9, 2, 5, 7, 7, 1, 1, 1, 2, 5, 8, 1, 1, 1, 9,
#        2, 1, 7, 1, 1, 2, 1, 7, 4, 7, 9, 1, 8, 8, 5, 5, 7, 1, 5, 2, 4, 1,
#        6, 1, 1, 0, 1, 2, 7, 7, 7, 1, 4, 1, 9, 2, 3, 1, 1, 4, 1, 1, 3, 1,
#        7, 2, 7, 2, 2, 9, 4, 1, 9, 7, 4, 0, 6, 1, 7, 1, 1, 4, 4, 6, 2, 2,
#        1, 9, 4, 9, 1, 1, 9, 1, 1, 0, 1, 3, 7, 1, 7, 1, 2, 3, 7, 9, 1, 1,
# ...

# %% [markdown]
# Membuat variable y_kmeans berdasarkan dari variable x

# %%
data['cluster'] = y_kmeans

# %% [markdown]
# Mendeskripsikan bahwa data cluster merupakan data y_kmeans

# %% [markdown]
# ## Pembentukan Visual/Grafik Cluster

# %%
plt.scatter(x[y_kmeans==0, 0], x[y_kmeans==0, 1], s=100, color='red')
plt.scatter(x[y_kmeans==1, 0], x[y_kmeans==1, 1], s=100, color='green')
plt.scatter(x[y_kmeans==2, 0], x[y_kmeans==2, 1], s=100, color='blue')
plt.scatter(x[y_kmeans==3, 0], x[y_kmeans==3, 1], s=100, color='cyan')
plt.scatter(x[y_kmeans==4, 0], x[y_kmeans==4, 1], s=100, color='magenta')
plt.scatter(x[y_kmeans==5, 0], x[y_kmeans==5, 1], s=100, color='black')
plt.scatter(x[y_kmeans==6, 0], x[y_kmeans==6, 1], s=100, color='orange')
plt.scatter(x[y_kmeans==7, 0], x[y_kmeans==7, 1], s=100, color='purple')
plt.scatter(x[y_kmeans==8, 0], x[y_kmeans==8, 1], s=100, color='gray')
plt.scatter(x[y_kmeans==9, 0], x[y_kmeans==9, 1], s=100, color='olive')

plt.title('Clusters Team PMPL PUBG')
plt.xlabel('Team Placement')
plt.ylabel('Team Kills')
plt.show()

# %% [markdown]
# Merupakan grafik dari 10 cluster berdasarkan dari data Placement dan Kill

# %% [markdown]
# ## Perhitungan Dataset Menggunakan Knn & Prediksi

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y_kmeans, test_size=0.3, random_state=0)

# %% [markdown]
# Membagi dataset menjadi 2 jenis data, yaitu data training dan data testing

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %% [markdown]
# Berfungsi untuk mengambil library standardscaler pada skcith learn preprocessing
# dan StandardScaler ini diubah menjadi sc (Pemanggil)
# dan 2 data dibawahnya berguna untuk mengatur scale pada x train dan juga x test

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 1)

# %% [markdown]
# Berfungsi untuk mengimport class KNeighborsClassifier pada sklearn.neighbors dan mengatur KNeighborsClassifier merupakan knn, dan data yang mendekatinya ada 1

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %% [markdown]
# Digunakan untuk melatih model K-Nearest Neighbors (KNN) dengan data latih dan label yang sesuai.

# %%
y_pred = knn.predict(x_test)
y_pred
# Out:
# array([4, 4, 3, 1, 4, 2, 1, 7, 7, 2, 1, 2, 5, 7, 7, 1, 3, 8, 7, 5, 8, 7,
#        6, 1, 1, 1, 9, 2, 1, 2, 7, 6, 7, 7, 1, 7, 2, 0, 7, 4, 7, 1, 1, 7,
#        4, 5, 1, 0, 7, 7, 2, 1, 4, 4, 2, 1, 6, 5, 5, 1, 6, 9, 9, 1, 0, 7,
#        7, 1, 1, 7, 2, 1, 7, 5, 7, 5, 1, 7, 5, 4, 4, 1, 6, 9, 4, 5, 4, 4,
#        2, 4, 1, 1, 9, 1, 7, 3, 9, 7, 1, 5, 9, 7, 9, 2, 9, 5, 5, 1, 7, 1,
#        1, 9, 5, 2, 1, 1, 1, 1, 1, 1, 5, 2, 1, 6, 1, 1, 1, 1, 1, 6, 4, 7,
#        5, 1, 7, 2, 7, 0, 1, 1, 6, 7, 9, 1, 1, 4, 4, 1, 0, 1])

# %% [markdown]
# Digunakan untuk mencari nilai y_pred yang merupakan data prekdisi dari x test

# %%
from sklearn.metrics import accuracy_score
print ("Akurasi Dataset yang didapatakan : ", accuracy_score(y_test,y_pred)*100)
# Out:
# Akurasi Dataset yang didapatakan :  98.66666666666667

# %% [markdown]
# Hasil akurasi dari dataset

# %% [markdown]
# ## Perhitungan Cluster - Davies Bouldin

# %%
from sklearn.metrics import davies_bouldin_score
label = kmeans.labels_
print ("Akurasi Cluster yang didapatkan :", davies_bouldin_score(x_scaled, label)*100)
# Out:
# Akurasi Cluster yang didapatkan : 79.90973751458131

# %% [markdown]
# Akurasi yang didapatkan dari perhitungan akurasi pada cluster menggunakan metode davies bouldin

# %%
x_scaled
# Out:
# array([[-0.62330229, -0.22759796],
#        [ 0.71919495,  0.07187304],
#        [-0.62330229, -0.82653997],
#        [-0.81508761, -0.82653997],
#        [-0.43151697,  0.67081505],
#        [-0.81508761, -0.82653997],
#        [-0.04794633,  0.97028605],
#        [ 0.52740963,  0.67081505],
#        [ 0.14383899, -0.82653997],
#        [ 1.86990688, -0.52706896],
#        [-0.62330229, -0.52706896],
#        [-0.23973165, -0.52706896],
#        [-0.62330229, -0.82653997],
#        [-0.81508761, -0.82653997],
#        [-0.62330229, -0.82653997],
#        [ 0.33562431, -0.22759796],
#        [ 1.10276559,  0.37134404],
#        [ 3.0206188 ,  4.86340908],
#        [-0.62330229, -0.82653997],
#        [-0.81508761, -0.82653997],
#        [-0.62330229, -0.82653997],
#        [ 0.33562431,  0.67081505],
#        [-0.04794633, -0.22759796],
#        [-0.81508761, -0.82653997],
#        [-0.43151697, -0.82653997],
#        [-0.81508761, -0.82653997],
#        [-0.62330229, -0.82653997],
# ...
